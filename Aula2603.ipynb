# %% [markdown]
# <a href="https://colab.research.google.com/github/zinhosilva/cnweb_2b2_b/blob/main/Aula2603.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exemplo de Serviço

# %%
def soma(a, b):
  return (a+b)

# %%
soma(8, 45)
# Out:
# 53

# %% [markdown]
# # Sistema de Equações

# %%
import math

def eq2grau(a, b, c):
  delta = b**2 - 4*a*c

  if delta == 0:
    return 'equação sem solução'
  else:

    x2 = (-b - math.sqrt(delta)) / (2*a)
    return x1, x2
# Out:
#   File "/tmp/ipykernel_21945/4210961896.py", line 6
#     if(delta == 0)
#                   ^
# SyntaxError: expected ':'

# %%
print(eq2grau(1, -3, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21945/2522592806.py in <cell line: 0>()
# ----> 1 print(eq2grau(1, -3, 2))
#
# NameError: name 'eq2grau' is not defined
